# %%
from data import *
from utils.augmentations import SSDAugmentation
from layers.modules import MultiBoxLoss
from ssd import build_ssd
import os
import sys
import time
import torch
from torch.autograd import Variable
import torch.nn as nn

import torch.optim as optim
import torch.backends.cudnn as cudnn
import torch.nn.init as init
import torch.utils.data as data
import numpy as np
import argparse

# %% [markdown]
# ## Argument Declare

# %%
DATASET_ROOT = "/home/alex/subt_ssd_training/data/subt_artifact"
DATASET_NAME = "extinguisher"
cfg = subt
BASE_NET = "./weights/vgg16_reducedfc.pth"
DATA_DETECTION = SUBTDetection
BATCH_SIZE = 2
PRETRAINED_MODEL = None
PRETRAINED_ITER = 0
SAVE_MODEL_ITER = 500
START_ITER = 0
NUM_WORKERS = 4
CUDA = True
LR = 1e-3
MOMENTUM = 0.4
WEIGHT_DECAY = 5e-4
GAMMA = 0.1
VISDOM = False
SAVE_FOLDER = "./weights/" + DATASET_NAME + "/"
if not os.path.exists(SAVE_FOLDER):
    os.makedirs(SAVE_FOLDER)

# %%
if torch.cuda.is_available():
    if not CUDA:
        print("WTF are u wasting your CUDA device?")
    else:
        torch.set_default_tensor_type('torch.cuda.FloatTensor')
else:
    torch.set_default_tensor_type('torch.FloatTensor')

# %% [markdown]
# ## Define function

# %%
def str2bool(v):
    return v.lower() in ("yes", "true", "t", "1")

# Initial model weights & bias
def xavier(param):
    init.xavier_uniform(param)
def weights_init(m):
    if isinstance(m, nn.Conv2d):
        xavier(m.weight.data)
        m.bias.data.zero_()

# Adjust learning rate during training
def adjust_learning_rate(optimizer, gamma, step):
    """Sets the learning rate to the initial LR decayed by 10 at every
        specified step
    # Adapted from PyTorch Imagenet example:
    # https://github.com/pytorch/examples/blob/master/imagenet/main.py
    """
    lr = LR * (gamma ** (step))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
        print("Change learning rate to: ", lr)

# %% [markdown]
# ## Create dataset

# %%
dataset = DATA_DETECTION(root=DATASET_ROOT, image_sets=['train'],transform=SSDAugmentation(cfg['min_dim'], MEANS))

classes = dataset.target_transform.class_to_ind
print("Class to index: \n", classes)
classes = sorted(classes.items(), key=lambda kv: kv[1])
label = []
for i in classes:
    label.append(i[0])
label.append('None')
print(label)
true_label = ['extinguisher']
# Out:
# Class to index:
#  {'extinguisher': 0}
# ['extinguisher', 'None']

# %% [markdown]
# ## Create model

# %%
# Delcare SSD Network
ssd_net = build_ssd('train', cfg['min_dim'], cfg['num_classes'])
net = ssd_net
if CUDA:
    net = torch.nn.DataParallel(ssd_net)
    cudnn.benchmark = True
    
if PRETRAINED_MODEL is not None: # Use SSD pretrained model
    print('Resuming training, loading {}...'.format(PRETRAINED_MODEL))
    ssd_net.load_weights(SAVE_FOLDER + PRETRAINED_MODEL)
else:
    print('Initializing weights...')
    vgg_weights = torch.load(BASE_NET) # load vgg pretrained model
    ssd_net.vgg.load_state_dict(vgg_weights)
    ssd_net.extras.apply(weights_init) # Initial SSD model weights & bias
    ssd_net.loc.apply(weights_init)
    ssd_net.conf.apply(weights_init)

optimizer = optim.SGD(net.parameters(), lr=LR, momentum=MOMENTUM,
                weight_decay=WEIGHT_DECAY)
criterion = MultiBoxLoss(BATCH_SIZE ,cfg['num_classes'], 0.5, True, 0, True, 3, 0.5,
                False, CUDA)
# Out:
# /home/alex/subt_ssd_training/ssd.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   self.priors = Variable(self.priorbox.forward(), volatile=True)
# /home/alex/subt_ssd_training/layers/modules/l2norm.py:17: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   init.constant(self.weight,self.gamma)
# Initializing weights...
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.

# %% [markdown]
# ## Training

# %% [markdown]
# ### Initialize

# %%
net.train()
# loss counters
loc_loss = 0
conf_loss = 0
epoch = 0
print('Loading the dataset...')
epoch_size = len(dataset) // BATCH_SIZE
print('Training SSD on:', DATASET_NAME)

data_loader = data.DataLoader(dataset, BATCH_SIZE,
                                num_workers=NUM_WORKERS,
                                shuffle=True, collate_fn=detection_collate,
                                pin_memory=True)
batch_iterator = iter(data_loader)
# Out:
# Loading the dataset...
# Training SSD on: extinguisher

# %% [markdown]
# ### Start training

# %%
step_index = 0
for iteration in range(START_ITER, cfg['max_iter']):
    if iteration in cfg['lr_steps']:
        step_index += 1
        adjust_learning_rate(optimizer, GAMMA, step_index)
    
    # make sure data iter not out of range
    try:
        images, targets = next(batch_iterator)
        #print(targets[0][0][4].item(), label[int(targets[0][0][4].item())])
    except StopIteration:
        batch_iterator = iter(data_loader)
        images, targets = next(batch_iterator)
    if CUDA:
        images = Variable(images.cuda())
        targets = [Variable(ann.cuda(), volatile=True) for ann in targets]
    else:
        images = Variable(images)
        targets = [Variable(ann, volatile=True) for ann in targets]
    
    # Forward
    t0 = time.time()
    out = net(images)
    # backprop
    optimizer.zero_grad()
    loss_l, loss_c = criterion(out, targets)
    loss = loss_l + loss_c
    loss.backward()
    optimizer.step()
    t1 = time.time()
    loc_loss += loss_l.item()
    conf_loss += loss_c.item()
    
    if iteration % 10 == 0:
            print('timer: %.4f sec.' % (t1 - t0))
            print('iter ' + repr(PRETRAINED_ITER + iteration) + ' || Loss: %.4f ||' % (loss.item()), end='')
    
    if iteration != 0 and iteration % SAVE_MODEL_ITER == 0:
            print('Saving state, iter:', iteration)
            torch.save(ssd_net.state_dict(), SAVE_FOLDER + DATASET_NAME + "_" +
                       repr(PRETRAINED_ITER + iteration) + '.pth')
# Save final model
torch.save(ssd_net.state_dict(),
            SAVE_FOLDER + DATASET_NAME + '.pth')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:16: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   app.launch_new_instance()
# /home/alex/.local/lib/python3.5/site-packages/torch/nn/_reduction.py:49: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# timer: 7.1010 sec.
# iter 0 || Loss: 22.1698 ||timer: 0.1709 sec.
# iter 10 || Loss: 8.6346 ||timer: 0.2172 sec.
# iter 20 || Loss: 9.9856 ||timer: 0.1749 sec.
# iter 30 || Loss: 14.6121 ||timer: 0.2011 sec.
# iter 40 || Loss: 6.5524 ||timer: 0.1714 sec.
# iter 50 || Loss: 8.0913 ||timer: 0.1926 sec.
# iter 60 || Loss: 11.2363 ||timer: 0.1716 sec.
# iter 70 || Loss: 6.6154 ||timer: 0.1712 sec.
# iter 80 || Loss: 5.1468 ||timer: 0.1711 sec.
# iter 90 || Loss: 7.0809 ||timer: 0.1716 sec.
# iter 100 || Loss: 5.9744 ||timer: 0.1712 sec.
# iter 110 || Loss: 5.5306 ||timer: 0.1815 sec.
# iter 120 || Loss: 7.1210 ||timer: 0.2661 sec.
# iter 130 || Loss: 5.7871 ||timer: 0.1943 sec.
# iter 140 || Loss: 6.9067 ||timer: 0.1783 sec.
# iter 150 || Loss: 7.9394 ||timer: 0.1711 sec.
# iter 160 || Loss: 6.2403 ||timer: 0.2049 sec.
# iter 170 || Loss: 5.1982 ||timer: 0.1713 sec.
# iter 180 || Loss: 6.5254 ||timer: 0.1829 sec.
# iter 190 || Loss: 5.8798 ||timer: 0.2031 sec.
# iter 200 || Loss: 6.0682 ||timer: 0.2117 sec.
# iter 210 || Loss: 7.2964 ||timer: 0.1822 sec.
# iter 220 || Loss: 15.8500 ||timer: 0.2019 sec.
# iter 230 || Loss: 5.3813 ||timer: 0.1714 sec.
# iter 240 || Loss: 6.4798 ||timer: 0.1762 sec.
# iter 250 || Loss: 5.0228 ||timer: 0.1866 sec.
# iter 260 || Loss: 6.3632 ||timer: 0.2612 sec.
# iter 270 || Loss: 8.6170 ||timer: 0.1726 sec.
# iter 280 || Loss: 6.6705 ||timer: 0.2482 sec.
# iter 290 || Loss: 5.6642 ||timer: 0.2801 sec.
# iter 300 || Loss: 6.7329 ||timer: 0.1743 sec.
# iter 310 || Loss: 5.6989 ||timer: 0.2267 sec.
# iter 320 || Loss: 6.9641 ||timer: 0.1760 sec.
# iter 330 || Loss: 6.2598 ||timer: 0.2129 sec.
# iter 340 || Loss: 11.0277 ||timer: 0.1866 sec.
# iter 350 || Loss: 5.7959 ||timer: 0.1769 sec.
# iter 360 || Loss: 5.5217 ||timer: 0.1763 sec.
# iter 370 || Loss: 9.2447 ||timer: 0.1712 sec.
# iter 380 || Loss: 5.4968 ||timer: 0.1711 sec.
# iter 390 || Loss: 5.5829 ||timer: 0.2624 sec.
# iter 400 || Loss: 7.2073 ||timer: 0.1978 sec.
# iter 410 || Loss: 5.6380 ||timer: 0.1826 sec.
# iter 420 || Loss: 4.7861 ||timer: 0.1995 sec.
# iter 430 || Loss: 5.4465 ||timer: 0.2513 sec.
# iter 440 || Loss: 5.3742 ||timer: 0.2260 sec.
# iter 450 || Loss: 5.6702 ||timer: 0.1719 sec.
# iter 460 || Loss: 5.5793 ||timer: 0.2271 sec.
# iter 470 || Loss: 4.9256 ||timer: 0.1729 sec.
# iter 480 || Loss: 11.1377 ||timer: 0.1996 sec.
# iter 490 || Loss: 6.4782 ||timer: 0.2478 sec.
# iter 500 || Loss: 5.2434 ||Saving state, iter: 500
# timer: 0.2483 sec.
# iter 510 || Loss: 5.9646 ||timer: 0.1726 sec.
# iter 520 || Loss: 5.0299 ||timer: 0.1728 sec.
# iter 530 || Loss: 4.2774 ||timer: 0.1894 sec.
# iter 540 || Loss: 5.6017 ||timer: 0.1914 sec.
# iter 550 || Loss: 3.5335 ||timer: 0.1762 sec.
# iter 560 || Loss: 4.6030 ||timer: 0.1737 sec.
# iter 570 || Loss: 5.5160 ||timer: 0.1775 sec.
# iter 580 || Loss: 8.8365 ||timer: 0.1756 sec.
# iter 590 || Loss: 6.0940 ||timer: 0.2504 sec.
# iter 600 || Loss: 5.9297 ||timer: 0.1965 sec.
# iter 610 || Loss: 4.2914 ||timer: 0.2177 sec.
# iter 620 || Loss: 2.5258 ||timer: 0.1741 sec.
# iter 630 || Loss: 5.8580 ||timer: 0.2221 sec.
# iter 640 || Loss: 4.4947 ||timer: 0.2599 sec.
# iter 650 || Loss: 4.7996 ||timer: 0.1755 sec.
# iter 660 || Loss: 6.1906 ||timer: 0.1741 sec.
# iter 670 || Loss: 3.8854 ||timer: 0.1745 sec.
# iter 680 || Loss: 4.2720 ||timer: 0.1766 sec.
# iter 690 || Loss: 4.7582 ||timer: 0.1766 sec.
# iter 700 || Loss: 3.2981 ||timer: 0.1764 sec.
# iter 710 || Loss: 4.0632 ||timer: 0.1784 sec.
# iter 720 || Loss: 4.8506 ||timer: 0.1760 sec.
# iter 730 || Loss: 4.4380 ||timer: 0.1783 sec.
# iter 740 || Loss: 4.6852 ||timer: 0.1779 sec.
# iter 750 || Loss: 4.0398 ||timer: 0.1763 sec.
# iter 760 || Loss: 4.7225 ||timer: 0.1792 sec.
# iter 770 || Loss: 4.3712 ||timer: 0.1973 sec.
# iter 780 || Loss: 3.6225 ||timer: 0.1765 sec.
# iter 790 || Loss: 8.6413 ||timer: 0.1964 sec.
# iter 800 || Loss: 4.1423 ||timer: 0.1806 sec.
# iter 810 || Loss: 3.2248 ||timer: 0.1779 sec.
# iter 820 || Loss: 7.0846 ||timer: 0.1764 sec.
# iter 830 || Loss: 3.2682 ||timer: 0.1767 sec.
# iter 840 || Loss: 7.0934 ||timer: 0.3355 sec.
# iter 850 || Loss: 3.6071 ||timer: 0.1804 sec.
# iter 860 || Loss: 4.7813 ||timer: 0.1781 sec.
# iter 870 || Loss: 2.8894 ||timer: 0.1762 sec.
# iter 880 || Loss: 3.0489 ||timer: 0.1752 sec.
# iter 890 || Loss: 7.4470 ||timer: 0.1840 sec.
# iter 900 || Loss: 5.5401 ||timer: 0.1789 sec.
# iter 910 || Loss: 3.2876 ||timer: 0.1868 sec.
# iter 920 || Loss: 4.2426 ||timer: 0.1761 sec.
# iter 930 || Loss: 7.2333 ||timer: 0.1782 sec.
# iter 940 || Loss: 5.1451 ||timer: 0.1773 sec.
# iter 950 || Loss: 2.9225 ||timer: 0.1783 sec.
# iter 960 || Loss: 3.7588 ||timer: 0.1908 sec.
# iter 970 || Loss: 2.7662 ||timer: 0.1766 sec.
# iter 980 || Loss: 4.7363 ||timer: 0.1785 sec.
# iter 990 || Loss: 4.3637 ||timer: 0.1991 sec.
# iter 1000 || Loss: 3.8421 ||Saving state, iter: 1000
# timer: 0.1786 sec.
# iter 1010 || Loss: 4.7158 ||timer: 0.1795 sec.
# iter 1020 || Loss: 3.8708 ||timer: 0.1868 sec.
# iter 1030 || Loss: 5.5737 ||timer: 0.2581 sec.
# iter 1040 || Loss: 3.5321 ||timer: 0.2530 sec.
# iter 1050 || Loss: 7.5187 ||timer: 0.2559 sec.
# iter 1060 || Loss: 3.4839 ||timer: 0.3046 sec.
# iter 1070 || Loss: 4.5402 ||timer: 0.1789 sec.
# iter 1080 || Loss: 6.1248 ||timer: 0.2568 sec.
# iter 1090 || Loss: 3.4266 ||timer: 0.1970 sec.
# iter 1100 || Loss: 3.8890 ||timer: 0.2047 sec.
# iter 1110 || Loss: 3.9996 ||timer: 0.1780 sec.
# iter 1120 || Loss: 6.9095 ||timer: 0.1848 sec.
# iter 1130 || Loss: 2.9089 ||timer: 0.1894 sec.
# iter 1140 || Loss: 6.9906 ||timer: 0.2205 sec.
# iter 1150 || Loss: 3.2977 ||timer: 0.1874 sec.
# iter 1160 || Loss: 1.6810 ||timer: 0.2671 sec.
# iter 1170 || Loss: 4.2080 ||timer: 0.1811 sec.
# iter 1180 || Loss: 3.6716 ||timer: 0.1794 sec.
# iter 1190 || Loss: 3.0966 ||timer: 0.1805 sec.
# iter 1200 || Loss: 5.3536 ||timer: 0.1811 sec.
# iter 1210 || Loss: 3.7267 ||timer: 0.1787 sec.
# iter 1220 || Loss: 3.2452 ||timer: 0.1811 sec.
# iter 1230 || Loss: 6.7474 ||timer: 0.1805 sec.
# iter 1240 || Loss: 3.4443 ||timer: 0.1787 sec.
# iter 1250 || Loss: 3.5838 ||timer: 0.1825 sec.
# iter 1260 || Loss: 2.7627 ||timer: 0.1958 sec.
# iter 1270 || Loss: 3.5278 ||timer: 0.1790 sec.
# iter 1280 || Loss: 4.7258 ||timer: 0.2022 sec.
# iter 1290 || Loss: 4.3556 ||timer: 0.1944 sec.
# iter 1300 || Loss: 1.4624 ||timer: 0.2187 sec.
# iter 1310 || Loss: 4.3524 ||timer: 0.2556 sec.
# iter 1320 || Loss: 3.9475 ||timer: 0.1787 sec.
# iter 1330 || Loss: 3.9025 ||timer: 0.1806 sec.
# iter 1340 || Loss: 4.8425 ||timer: 0.1813 sec.
# iter 1350 || Loss: 4.3965 ||timer: 0.2088 sec.
# iter 1360 || Loss: 4.0710 ||timer: 0.1851 sec.
# iter 1370 || Loss: 3.4377 ||timer: 0.2492 sec.
# iter 1380 || Loss: 4.9329 ||timer: 0.1784 sec.
# iter 1390 || Loss: 2.9846 ||timer: 0.2881 sec.
# iter 1400 || Loss: 1.9730 ||timer: 0.1832 sec.
# iter 1410 || Loss: 4.4821 ||timer: 0.2752 sec.
# iter 1420 || Loss: 3.3813 ||timer: 0.1308 sec.
# iter 1430 || Loss: 6.6616 ||timer: 0.2449 sec.
# iter 1440 || Loss: 3.5466 ||timer: 0.2517 sec.
# iter 1450 || Loss: 5.9584 ||timer: 0.2513 sec.
# iter 1460 || Loss: 2.5324 ||timer: 0.2465 sec.
# iter 1470 || Loss: 3.0323 ||timer: 0.2528 sec.
# iter 1480 || Loss: 3.7967 ||timer: 0.1776 sec.
# iter 1490 || Loss: 4.2578 ||timer: 0.1786 sec.
# iter 1500 || Loss: 2.7027 ||Saving state, iter: 1500
# timer: 0.1790 sec.
# iter 1510 || Loss: 3.1643 ||timer: 0.1851 sec.
# iter 1520 || Loss: 6.2423 ||timer: 0.1836 sec.
# iter 1530 || Loss: 4.4643 ||timer: 0.1805 sec.
# iter 1540 || Loss: 2.2207 ||timer: 0.1823 sec.
# iter 1550 || Loss: 3.4318 ||timer: 0.1806 sec.
# iter 1560 || Loss: 2.3684 ||timer: 0.1820 sec.
# iter 1570 || Loss: 2.7531 ||timer: 0.1938 sec.
# iter 1580 || Loss: 5.3035 ||timer: 0.5339 sec.
# iter 1590 || Loss: 5.4901 ||timer: 0.1743 sec.
# iter 1600 || Loss: 2.6342 ||timer: 0.2976 sec.
# iter 1610 || Loss: 3.1971 ||timer: 0.1776 sec.
# iter 1620 || Loss: 3.1026 ||timer: 0.2041 sec.
# iter 1630 || Loss: 2.6941 ||timer: 0.1766 sec.
# iter 1640 || Loss: 3.2549 ||timer: 0.1811 sec.
# iter 1650 || Loss: 3.8840 ||timer: 0.1787 sec.
# iter 1660 || Loss: 7.3850 ||timer: 0.6740 sec.
# iter 1670 || Loss: 2.5333 ||timer: 0.1800 sec.
# iter 1680 || Loss: 4.1265 ||timer: 0.3880 sec.
# iter 1690 || Loss: 3.9993 ||timer: 0.1863 sec.
# iter 1700 || Loss: 1.8654 ||timer: 0.1952 sec.
# iter 1710 || Loss: 3.3551 ||timer: 0.2055 sec.
# iter 1720 || Loss: 2.3450 ||timer: 0.1932 sec.
# iter 1730 || Loss: 5.5663 ||timer: 0.1962 sec.
# iter 1740 || Loss: 2.7589 ||timer: 0.2045 sec.
# iter 1750 || Loss: 3.4210 ||timer: 0.1935 sec.
# iter 1760 || Loss: 3.4140 ||timer: 0.1898 sec.
# iter 1770 || Loss: 3.1086 ||timer: 0.1815 sec.
# iter 1780 || Loss: 2.0765 ||timer: 0.2322 sec.
# iter 1790 || Loss: 4.1076 ||timer: 0.1988 sec.
# iter 1800 || Loss: 1.5070 ||timer: 0.1953 sec.
# iter 1810 || Loss: 1.3601 ||timer: 0.2243 sec.
# iter 1820 || Loss: 2.8022 ||timer: 0.1813 sec.
# iter 1830 || Loss: 2.9460 ||timer: 0.1791 sec.
# iter 1840 || Loss: 3.6769 ||timer: 0.1868 sec.
# iter 1850 || Loss: 2.4628 ||timer: 0.1822 sec.
# iter 1860 || Loss: 5.0113 ||timer: 0.1812 sec.
# iter 1870 || Loss: 4.0642 ||timer: 0.2029 sec.
# iter 1880 || Loss: 1.6052 ||timer: 0.6272 sec.
# iter 1890 || Loss: 11.2008 ||timer: 0.1995 sec.
# iter 1900 || Loss: 3.0381 ||timer: 0.1771 sec.
# iter 1910 || Loss: 2.3383 ||timer: 0.1756 sec.
# iter 1920 || Loss: 7.9220 ||timer: 0.1786 sec.
# iter 1930 || Loss: 3.9663 ||timer: 0.1788 sec.
# iter 1940 || Loss: 3.8934 ||timer: 0.2121 sec.
# iter 1950 || Loss: 2.0217 ||timer: 0.1844 sec.
# iter 1960 || Loss: 1.6757 ||timer: 0.1808 sec.
# iter 1970 || Loss: 6.5008 ||timer: 0.1787 sec.
# iter 1980 || Loss: 2.7617 ||timer: 0.1921 sec.
# iter 1990 || Loss: 2.9958 ||timer: 0.1786 sec.
# iter 2000 || Loss: 2.2495 ||Saving state, iter: 2000
# timer: 0.1818 sec.
# iter 2010 || Loss: 3.1738 ||timer: 0.1848 sec.
# iter 2020 || Loss: 2.2899 ||timer: 0.1847 sec.
# iter 2030 || Loss: 2.7351 ||timer: 0.1975 sec.
# iter 2040 || Loss: 7.3221 ||timer: 0.1830 sec.
# iter 2050 || Loss: 6.6581 ||timer: 0.3104 sec.
# iter 2060 || Loss: 3.1095 ||timer: 0.2490 sec.
# iter 2070 || Loss: 3.2664 ||timer: 0.2876 sec.
# iter 2080 || Loss: 2.1992 ||timer: 0.5333 sec.
# iter 2090 || Loss: 3.7744 ||timer: 0.2499 sec.
# iter 2100 || Loss: 3.0693 ||timer: 0.1754 sec.
# iter 2110 || Loss: 4.6168 ||timer: 0.4950 sec.
# iter 2120 || Loss: 2.8825 ||timer: 0.4743 sec.
# iter 2130 || Loss: 2.4229 ||timer: 0.1809 sec.
# iter 2140 || Loss: 2.5207 ||timer: 0.1871 sec.
# iter 2150 || Loss: 2.8308 ||timer: 0.1856 sec.
# iter 2160 || Loss: 5.2165 ||timer: 0.3338 sec.
# iter 2170 || Loss: 2.1249 ||timer: 0.1791 sec.
# iter 2180 || Loss: 7.2196 ||timer: 0.1830 sec.
# iter 2190 || Loss: 5.8660 ||timer: 0.2430 sec.
# iter 2200 || Loss: 4.2547 ||timer: 0.2514 sec.
# iter 2210 || Loss: 2.1056 ||timer: 0.2478 sec.
# iter 2220 || Loss: 7.4353 ||timer: 0.2537 sec.
# iter 2230 || Loss: 2.1597 ||timer: 0.1863 sec.
# iter 2240 || Loss: 3.9355 ||timer: 0.1786 sec.
# iter 2250 || Loss: 2.3311 ||timer: 0.2632 sec.
# iter 2260 || Loss: 2.6471 ||timer: 0.2206 sec.
# iter 2270 || Loss: 4.2008 ||timer: 0.1810 sec.
# iter 2280 || Loss: 4.2419 ||timer: 0.1787 sec.
# iter 2290 || Loss: 2.0177 ||timer: 0.2486 sec.
# iter 2300 || Loss: 3.0553 ||timer: 0.1824 sec.
# iter 2310 || Loss: 8.2893 ||timer: 0.1989 sec.
# iter 2320 || Loss: 4.6172 ||timer: 0.1909 sec.
# iter 2330 || Loss: 1.9882 ||timer: 0.2450 sec.
# iter 2340 || Loss: 1.9477 ||timer: 0.1843 sec.
# iter 2350 || Loss: 2.1820 ||timer: 0.1843 sec.
# iter 2360 || Loss: 2.8680 ||timer: 0.2486 sec.
# iter 2370 || Loss: 2.3055 ||timer: 0.2362 sec.
# iter 2380 || Loss: 1.9390 ||timer: 0.2929 sec.
# iter 2390 || Loss: 4.8128 ||timer: 0.2456 sec.
# iter 2400 || Loss: 3.8046 ||timer: 0.2455 sec.
# iter 2410 || Loss: 3.9806 ||timer: 0.1867 sec.
# iter 2420 || Loss: 8.1181 ||timer: 0.1821 sec.
# iter 2430 || Loss: 4.7990 ||timer: 0.1837 sec.
# iter 2440 || Loss: 2.4019 ||timer: 0.1928 sec.
# iter 2450 || Loss: 1.8460 ||timer: 0.1813 sec.
# iter 2460 || Loss: 1.4791 ||timer: 0.2618 sec.
# iter 2470 || Loss: 3.3497 ||timer: 0.1806 sec.
# iter 2480 || Loss: 3.7845 ||timer: 0.1820 sec.
# iter 2490 || Loss: 2.7299 ||timer: 0.1880 sec.
# iter 2500 || Loss: 5.1873 ||Saving state, iter: 2500
# timer: 0.2135 sec.
# iter 2510 || Loss: 2.6262 ||timer: 0.1799 sec.
# iter 2520 || Loss: 4.5879 ||timer: 0.2048 sec.
# iter 2530 || Loss: 2.4931 ||timer: 0.1854 sec.
# iter 2540 || Loss: 4.8080 ||timer: 0.1997 sec.
# iter 2550 || Loss: 5.6780 ||timer: 0.2485 sec.
# iter 2560 || Loss: 5.1263 ||timer: 0.2170 sec.
# iter 2570 || Loss: 2.0677 ||timer: 0.2402 sec.
# iter 2580 || Loss: 1.6597 ||timer: 0.2434 sec.
# iter 2590 || Loss: 2.1795 ||timer: 0.2512 sec.
# iter 2600 || Loss: 4.1029 ||timer: 0.2393 sec.
# iter 2610 || Loss: 2.5183 ||timer: 0.2093 sec.
# iter 2620 || Loss: 3.6118 ||timer: 0.2505 sec.
# iter 2630 || Loss: 1.4357 ||timer: 0.2591 sec.
# iter 2640 || Loss: 1.8064 ||timer: 0.2269 sec.
# iter 2650 || Loss: 1.2699 ||timer: 0.2546 sec.
# iter 2660 || Loss: 3.0507 ||timer: 0.2102 sec.
# iter 2670 || Loss: 2.7425 ||timer: 0.1814 sec.
# iter 2680 || Loss: 1.9800 ||timer: 0.1858 sec.
# iter 2690 || Loss: 2.6240 ||timer: 0.2368 sec.
# iter 2700 || Loss: 4.0159 ||timer: 0.2680 sec.
# iter 2710 || Loss: 4.1570 ||timer: 0.1793 sec.
# iter 2720 || Loss: 3.4116 ||timer: 0.2016 sec.
# iter 2730 || Loss: 1.4553 ||timer: 0.1971 sec.
# iter 2740 || Loss: 2.5278 ||timer: 0.1850 sec.
# iter 2750 || Loss: 2.8630 ||timer: 0.1798 sec.
# iter 2760 || Loss: 2.6713 ||timer: 0.1794 sec.
# iter 2770 || Loss: 2.2385 ||timer: 0.2088 sec.
# iter 2780 || Loss: 1.3546 ||timer: 0.2676 sec.
# iter 2790 || Loss: 4.4450 ||timer: 0.2489 sec.
# iter 2800 || Loss: 3.6525 ||timer: 0.2493 sec.
# iter 2810 || Loss: 1.7804 ||timer: 0.2375 sec.
# iter 2820 || Loss: 5.1609 ||timer: 0.2437 sec.
# iter 2830 || Loss: 2.0541 ||timer: 0.2492 sec.
# iter 2840 || Loss: 1.7575 ||timer: 0.2178 sec.
# iter 2850 || Loss: 1.7157 ||timer: 0.1815 sec.
# iter 2860 || Loss: 1.3410 ||timer: 0.1817 sec.
# iter 2870 || Loss: 2.6303 ||timer: 0.1819 sec.
# iter 2880 || Loss: 2.0021 ||timer: 0.2802 sec.
# iter 2890 || Loss: 1.6904 ||timer: 0.2922 sec.
# iter 2900 || Loss: 3.3247 ||timer: 0.2469 sec.
# iter 2910 || Loss: 2.8317 ||timer: 0.2081 sec.
# iter 2920 || Loss: 1.4279 ||timer: 0.1879 sec.
# iter 2930 || Loss: 1.9676 ||timer: 0.1883 sec.
# iter 2940 || Loss: 3.0379 ||timer: 0.1883 sec.
# iter 2950 || Loss: 5.9789 ||timer: 0.1876 sec.
# iter 2960 || Loss: 2.3116 ||timer: 0.1881 sec.
# iter 2970 || Loss: 2.5087 ||timer: 0.1895 sec.
# iter 2980 || Loss: 2.4778 ||timer: 0.1897 sec.
# iter 2990 || Loss: 3.5724 ||timer: 0.1886 sec.
# iter 3000 || Loss: 1.2413 ||Saving state, iter: 3000
# timer: 0.1872 sec.
# iter 3010 || Loss: 2.5928 ||timer: 0.1870 sec.
# iter 3020 || Loss: 1.5729 ||timer: 0.1961 sec.
# iter 3030 || Loss: 3.0546 ||timer: 0.1870 sec.
# iter 3040 || Loss: 2.0130 ||timer: 0.1874 sec.
# iter 3050 || Loss: 2.2198 ||timer: 0.1878 sec.
# iter 3060 || Loss: 4.0706 ||timer: 0.1877 sec.
# iter 3070 || Loss: 1.9457 ||timer: 0.1875 sec.
# iter 3080 || Loss: 2.7966 ||timer: 0.1875 sec.
# iter 3090 || Loss: 1.5093 ||timer: 0.1890 sec.
# iter 3100 || Loss: 2.2013 ||timer: 0.1870 sec.
# iter 3110 || Loss: 2.8171 ||timer: 0.1871 sec.
# iter 3120 || Loss: 4.2979 ||timer: 0.1877 sec.
# iter 3130 || Loss: 4.8291 ||timer: 0.1869 sec.
# iter 3140 || Loss: 3.5656 ||timer: 0.1870 sec.
# iter 3150 || Loss: 1.3251 ||timer: 0.1896 sec.
# iter 3160 || Loss: 2.8141 ||timer: 0.1872 sec.
# iter 3170 || Loss: 5.2891 ||timer: 0.1871 sec.
# iter 3180 || Loss: 4.0091 ||timer: 0.1875 sec.
# iter 3190 || Loss: 2.2230 ||timer: 0.1869 sec.
# iter 3200 || Loss: 1.6860 ||timer: 0.1872 sec.
# iter 3210 || Loss: 5.2260 ||timer: 0.1874 sec.
# iter 3220 || Loss: 3.0877 ||timer: 0.1963 sec.
# iter 3230 || Loss: 2.1301 ||timer: 0.1876 sec.
# iter 3240 || Loss: 2.0605 ||timer: 0.1876 sec.
# iter 3250 || Loss: 1.4240 ||timer: 0.1874 sec.
# iter 3260 || Loss: 1.3443 ||timer: 0.1876 sec.
# iter 3270 || Loss: 2.0168 ||timer: 0.1871 sec.
# iter 3280 || Loss: 1.2064 ||timer: 0.1869 sec.
# iter 3290 || Loss: 1.2692 ||timer: 0.1872 sec.
# iter 3300 || Loss: 6.6693 ||timer: 0.1871 sec.
# iter 3310 || Loss: 2.9996 ||timer: 0.1870 sec.
# iter 3320 || Loss: 2.1783 ||timer: 0.1878 sec.
# iter 3330 || Loss: 2.1050 ||timer: 0.1850 sec.
# iter 3340 || Loss: 2.3598 ||timer: 0.1847 sec.
# iter 3350 || Loss: 2.9249 ||timer: 0.1848 sec.
# iter 3360 || Loss: 2.4440 ||timer: 0.1852 sec.
# iter 3370 || Loss: 2.0891 ||timer: 0.1909 sec.
# iter 3380 || Loss: 2.6460 ||timer: 0.1846 sec.
# iter 3390 || Loss: 4.5858 ||timer: 0.1848 sec.
# iter 3400 || Loss: 2.1935 ||timer: 0.1852 sec.
# iter 3410 || Loss: 1.1465 ||timer: 0.1873 sec.
# iter 3420 || Loss: 1.3315 ||timer: 0.1871 sec.
# iter 3430 || Loss: 1.8112 ||timer: 0.1870 sec.
# iter 3440 || Loss: 3.0032 ||timer: 0.1872 sec.
# iter 3450 || Loss: 4.0237 ||timer: 0.1874 sec.
# iter 3460 || Loss: 3.1687 ||timer: 0.1869 sec.
# iter 3470 || Loss: 2.3747 ||timer: 0.1870 sec.
# iter 3480 || Loss: 1.8512 ||timer: 0.1874 sec.
# iter 3490 || Loss: 3.0116 ||timer: 0.1875 sec.
# iter 3500 || Loss: 2.2305 ||Saving state, iter: 3500
# timer: 0.1888 sec.
# iter 3510 || Loss: 1.9722 ||timer: 0.1869 sec.
# iter 3520 || Loss: 9.0684 ||timer: 0.1879 sec.
# iter 3530 || Loss: 3.5611 ||timer: 0.1880 sec.
# iter 3540 || Loss: 2.3229 ||timer: 0.1873 sec.
# iter 3550 || Loss: 2.1862 ||timer: 0.1878 sec.
# iter 3560 || Loss: 1.8860 ||timer: 0.1872 sec.
# iter 3570 || Loss: 2.2478 ||timer: 0.1870 sec.
# iter 3580 || Loss: 1.0655 ||timer: 0.1871 sec.
# iter 3590 || Loss: 4.7687 ||timer: 0.1875 sec.
# iter 3600 || Loss: 1.6343 ||timer: 0.1920 sec.
# iter 3610 || Loss: 2.4050 ||timer: 0.1870 sec.
# iter 3620 || Loss: 4.0056 ||timer: 0.1875 sec.
# iter 3630 || Loss: 3.8140 ||timer: 0.1875 sec.
# iter 3640 || Loss: 1.4146 ||timer: 0.1873 sec.
# iter 3650 || Loss: 2.1448 ||timer: 0.1869 sec.
# iter 3660 || Loss: 5.8601 ||timer: 0.1881 sec.
# iter 3670 || Loss: 1.0415 ||timer: 0.1877 sec.
# iter 3680 || Loss: 1.2773 ||timer: 0.1870 sec.
# iter 3690 || Loss: 2.8196 ||timer: 0.1869 sec.
# iter 3700 || Loss: 1.4919 ||timer: 0.1872 sec.
# iter 3710 || Loss: 1.3808 ||timer: 0.1873 sec.
# iter 3720 || Loss: 3.8773 ||timer: 0.1875 sec.
# iter 3730 || Loss: 0.9617 ||timer: 0.1873 sec.
# iter 3740 || Loss: 4.7584 ||timer: 0.1873 sec.
# iter 3750 || Loss: 3.1145 ||timer: 0.1874 sec.
# iter 3760 || Loss: 4.7644 ||timer: 0.1873 sec.
# iter 3770 || Loss: 2.2750 ||timer: 0.1902 sec.
# iter 3780 || Loss: 1.2041 ||timer: 0.1874 sec.
# iter 3790 || Loss: 2.3052 ||timer: 0.1881 sec.
# iter 3800 || Loss: 2.8622 ||timer: 0.1875 sec.
# iter 3810 || Loss: 2.8789 ||timer: 0.1874 sec.
# iter 3820 || Loss: 5.0075 ||timer: 0.1870 sec.
# iter 3830 || Loss: 1.9563 ||timer: 0.1916 sec.
# iter 3840 || Loss: 4.2437 ||timer: 0.1870 sec.
# iter 3850 || Loss: 1.6205 ||timer: 0.1871 sec.
# iter 3860 || Loss: 2.8225 ||timer: 0.1871 sec.
# iter 3870 || Loss: 3.6432 ||timer: 0.1870 sec.
# iter 3880 || Loss: 3.3179 ||timer: 0.1868 sec.
# iter 3890 || Loss: 2.1309 ||timer: 0.1904 sec.
# iter 3900 || Loss: 1.3368 ||timer: 0.1873 sec.
# iter 3910 || Loss: 1.8654 ||timer: 0.1872 sec.
# iter 3920 || Loss: 3.8432 ||timer: 0.1869 sec.
# iter 3930 || Loss: 3.7751 ||timer: 0.1900 sec.
# iter 3940 || Loss: 3.3475 ||timer: 0.1870 sec.
# iter 3950 || Loss: 2.2712 ||timer: 0.1874 sec.
# iter 3960 || Loss: 1.9920 ||timer: 0.1869 sec.
# iter 3970 || Loss: 1.2686 ||timer: 0.1869 sec.
# iter 3980 || Loss: 3.9133 ||timer: 0.1876 sec.
# iter 3990 || Loss: 1.5970 ||Change learning rate to:  0.0001
# timer: 0.1919 sec.
# iter 4000 || Loss: 1.4588 ||Saving state, iter: 4000
# timer: 0.1870 sec.
# iter 4010 || Loss: 1.7390 ||timer: 0.1869 sec.
# iter 4020 || Loss: 1.3140 ||timer: 0.1873 sec.
# iter 4030 || Loss: 1.4465 ||timer: 0.1895 sec.
# iter 4040 || Loss: 2.9121 ||timer: 0.1872 sec.
# iter 4050 || Loss: 1.7931 ||timer: 0.1875 sec.
# iter 4060 || Loss: 2.6916 ||timer: 0.1871 sec.
# iter 4070 || Loss: 1.7691 ||timer: 0.1874 sec.
# iter 4080 || Loss: 1.7478 ||timer: 0.1871 sec.
# iter 4090 || Loss: 0.9305 ||timer: 0.1880 sec.
# iter 4100 || Loss: 0.8070 ||timer: 0.1872 sec.
# iter 4110 || Loss: 1.3580 ||timer: 0.1876 sec.
# iter 4120 || Loss: 1.6959 ||timer: 0.1872 sec.
# iter 4130 || Loss: 0.9615 ||timer: 0.1901 sec.
# iter 4140 || Loss: 1.8072 ||timer: 0.1877 sec.
# iter 4150 || Loss: 1.4119 ||timer: 0.1872 sec.
# iter 4160 || Loss: 1.0576 ||timer: 0.1949 sec.
# iter 4170 || Loss: 2.2702 ||timer: 0.1871 sec.
# iter 4180 || Loss: 4.0786 ||timer: 0.1871 sec.
# iter 4190 || Loss: 4.2024 ||timer: 0.1871 sec.
# iter 4200 || Loss: 1.1080 ||timer: 0.1877 sec.
# iter 4210 || Loss: 2.6225 ||timer: 0.1871 sec.
# iter 4220 || Loss: 2.9737 ||timer: 0.1901 sec.
# iter 4230 || Loss: 2.4190 ||timer: 0.1878 sec.
# iter 4240 || Loss: 1.5105 ||timer: 0.1873 sec.
# iter 4250 || Loss: 1.0842 ||timer: 0.1870 sec.
# iter 4260 || Loss: 1.6214 ||timer: 0.1880 sec.
# iter 4270 || Loss: 1.8995 ||timer: 0.1875 sec.
# iter 4280 || Loss: 1.0394 ||timer: 0.1873 sec.
# iter 4290 || Loss: 1.3090 ||timer: 0.1879 sec.
# iter 4300 || Loss: 1.3734 ||timer: 0.1914 sec.
# iter 4310 || Loss: 2.9750 ||timer: 0.1887 sec.
# iter 4320 || Loss: 6.5775 ||timer: 0.1871 sec.
# iter 4330 || Loss: 3.2885 ||timer: 0.1876 sec.
# iter 4340 || Loss: 1.1647 ||timer: 0.1868 sec.
# iter 4350 || Loss: 1.9940 ||timer: 0.1872 sec.
# iter 4360 || Loss: 1.9780 ||timer: 0.1922 sec.
# iter 4370 || Loss: 2.1761 ||timer: 0.1872 sec.
# iter 4380 || Loss: 5.9822 ||timer: 0.1871 sec.
# iter 4390 || Loss: 1.8539 ||timer: 0.1869 sec.
# iter 4400 || Loss: 1.1719 ||timer: 0.1871 sec.
# iter 4410 || Loss: 1.7189 ||timer: 0.1875 sec.
# iter 4420 || Loss: 1.3952 ||timer: 0.1871 sec.
# iter 4430 || Loss: 0.8924 ||timer: 0.1904 sec.
# iter 4440 || Loss: 0.8160 ||timer: 0.1872 sec.
# iter 4450 || Loss: 1.4897 ||timer: 0.1876 sec.
# iter 4460 || Loss: 1.2752 ||timer: 0.1875 sec.
# iter 4470 || Loss: 1.1992 ||timer: 0.1872 sec.
# iter 4480 || Loss: 1.0265 ||timer: 0.1868 sec.
# iter 4490 || Loss: 1.1216 ||timer: 0.1874 sec.
# iter 4500 || Loss: 1.9956 ||Saving state, iter: 4500
# timer: 0.1870 sec.
# iter 4510 || Loss: 3.7473 ||timer: 0.1872 sec.
# iter 4520 || Loss: 1.3502 ||timer: 0.1874 sec.
# iter 4530 || Loss: 1.8951 ||timer: 0.1873 sec.
# iter 4540 || Loss: 1.1079 ||timer: 0.1873 sec.
# iter 4550 || Loss: 2.1795 ||timer: 0.1877 sec.
# iter 4560 || Loss: 2.3892 ||timer: 0.1873 sec.
# iter 4570 || Loss: 0.9341 ||timer: 0.1875 sec.
# iter 4580 || Loss: 1.9966 ||timer: 0.1875 sec.
# iter 4590 || Loss: 1.1318 ||timer: 0.1870 sec.
# iter 4600 || Loss: 1.5492 ||timer: 0.1874 sec.
# iter 4610 || Loss: 3.1753 ||timer: 0.1896 sec.
# iter 4620 || Loss: 3.2564 ||timer: 0.1869 sec.
# iter 4630 || Loss: 2.3544 ||timer: 0.1875 sec.
# iter 4640 || Loss: 2.3624 ||timer: 0.1872 sec.
# iter 4650 || Loss: 2.4306 ||timer: 0.1871 sec.
# iter 4660 || Loss: 0.7394 ||timer: 0.2119 sec.
# iter 4670 || Loss: 1.1572 ||timer: 0.1875 sec.
# iter 4680 || Loss: 1.3586 ||timer: 0.1882 sec.
# iter 4690 || Loss: 3.4126 ||timer: 0.1879 sec.
# iter 4700 || Loss: 4.0199 ||timer: 0.1871 sec.
# iter 4710 || Loss: 1.3460 ||timer: 0.1875 sec.
# iter 4720 || Loss: 0.5206 ||timer: 0.1877 sec.
# iter 4730 || Loss: 2.8705 ||timer: 0.1870 sec.
# iter 4740 || Loss: 1.8791 ||timer: 0.1873 sec.
# iter 4750 || Loss: 1.6540 ||timer: 0.1872 sec.
# iter 4760 || Loss: 2.1647 ||timer: 0.1946 sec.
# iter 4770 || Loss: 1.8875 ||timer: 0.1875 sec.
# iter 4780 || Loss: 2.9375 ||timer: 0.1872 sec.
# iter 4790 || Loss: 1.3250 ||timer: 0.1875 sec.
# iter 4800 || Loss: 0.5386 ||timer: 0.1871 sec.
# iter 4810 || Loss: 1.3514 ||timer: 0.1871 sec.
# iter 4820 || Loss: 4.2382 ||timer: 0.1877 sec.
# iter 4830 || Loss: 6.5784 ||timer: 0.1922 sec.
# iter 4840 || Loss: 2.2188 ||timer: 0.1915 sec.
# iter 4850 || Loss: 5.2043 ||timer: 0.1877 sec.
# iter 4860 || Loss: 0.8344 ||timer: 0.1871 sec.
# iter 4870 || Loss: 1.3416 ||timer: 0.1871 sec.
# iter 4880 || Loss: 2.0093 ||timer: 0.1872 sec.
# iter 4890 || Loss: 2.2714 ||timer: 0.1878 sec.
# iter 4900 || Loss: 1.7315 ||timer: 0.1883 sec.
# iter 4910 || Loss: 1.2417 ||timer: 0.1874 sec.
# iter 4920 || Loss: 2.0935 ||timer: 0.1903 sec.
# iter 4930 || Loss: 0.9972 ||timer: 0.1873 sec.
# iter 4940 || Loss: 2.1719 ||timer: 0.1876 sec.
# iter 4950 || Loss: 1.1565 ||timer: 0.1875 sec.
# iter 4960 || Loss: 1.8905 ||timer: 0.1870 sec.
# iter 4970 || Loss: 0.9379 ||timer: 0.1870 sec.
# iter 4980 || Loss: 1.6322 ||timer: 0.1873 sec.
# iter 4990 || Loss: 2.5234 ||timer: 0.1873 sec.
# iter 5000 || Loss: 2.8799 ||Saving state, iter: 5000
# timer: 0.1876 sec.
# iter 5010 || Loss: 2.2484 ||timer: 0.1873 sec.
# iter 5020 || Loss: 0.8572 ||timer: 0.1871 sec.
# iter 5030 || Loss: 1.9204 ||timer: 0.1874 sec.
# iter 5040 || Loss: 1.3975 ||timer: 0.1873 sec.
# iter 5050 || Loss: 3.4559 ||timer: 0.1870 sec.
# iter 5060 || Loss: 1.3039 ||timer: 0.1871 sec.
# iter 5070 || Loss: 1.0536 ||timer: 0.1875 sec.
# iter 5080 || Loss: 1.2518 ||timer: 0.1874 sec.
# iter 5090 || Loss: 6.0957 ||timer: 0.1875 sec.
# iter 5100 || Loss: 2.5727 ||timer: 0.1871 sec.
# iter 5110 || Loss: 3.1558 ||timer: 0.1869 sec.
# iter 5120 || Loss: 1.2603 ||timer: 0.1968 sec.
# iter 5130 || Loss: 1.0574 ||timer: 0.1874 sec.
# iter 5140 || Loss: 1.7298 ||timer: 0.1869 sec.
# iter 5150 || Loss: 2.0069 ||timer: 0.1876 sec.
# iter 5160 || Loss: 1.1869 ||timer: 0.1873 sec.
# iter 5170 || Loss: 1.5489 ||timer: 0.1872 sec.
# iter 5180 || Loss: 3.4103 ||timer: 0.1871 sec.
# iter 5190 || Loss: 1.6405 ||timer: 0.1876 sec.
# iter 5200 || Loss: 3.8117 ||timer: 0.1878 sec.
# iter 5210 || Loss: 2.1732 ||timer: 0.1868 sec.
# iter 5220 || Loss: 1.1015 ||timer: 0.1873 sec.
# iter 5230 || Loss: 0.4955 ||timer: 0.1870 sec.
# iter 5240 || Loss: 1.9268 ||timer: 0.1924 sec.
# iter 5250 || Loss: 1.0387 ||timer: 0.1875 sec.
# iter 5260 || Loss: 0.7639 ||timer: 0.1873 sec.
# iter 5270 || Loss: 1.9600 ||timer: 0.1876 sec.
# iter 5280 || Loss: 1.9734 ||timer: 0.1873 sec.
# iter 5290 || Loss: 1.5977 ||timer: 0.1874 sec.
# iter 5300 || Loss: 2.0118 ||timer: 0.1871 sec.
# iter 5310 || Loss: 2.6939 ||timer: 0.1876 sec.
# iter 5320 || Loss: 3.8336 ||timer: 0.1869 sec.
# iter 5330 || Loss: 0.8050 ||timer: 0.1870 sec.
# iter 5340 || Loss: 1.5382 ||timer: 0.1872 sec.
# iter 5350 || Loss: 2.2740 ||timer: 0.1871 sec.
# iter 5360 || Loss: 2.6046 ||timer: 0.1873 sec.
# iter 5370 || Loss: 1.0187 ||timer: 0.1876 sec.
# iter 5380 || Loss: 0.8305 ||timer: 0.1876 sec.
# iter 5390 || Loss: 1.8035 ||timer: 0.1872 sec.
# iter 5400 || Loss: 0.4639 ||timer: 0.1875 sec.
# iter 5410 || Loss: 0.7555 ||timer: 0.1874 sec.
# iter 5420 || Loss: 0.8555 ||timer: 0.1873 sec.
# iter 5430 || Loss: 1.1132 ||timer: 0.1868 sec.
# iter 5440 || Loss: 1.2882 ||timer: 0.1873 sec.
# iter 5450 || Loss: 2.3131 ||timer: 0.1875 sec.
# iter 5460 || Loss: 1.7432 ||timer: 0.1870 sec.
# iter 5470 || Loss: 0.9934 ||timer: 0.1871 sec.
# iter 5480 || Loss: 1.7836 ||timer: 0.1869 sec.
# iter 5490 || Loss: 0.9761 ||timer: 0.1871 sec.
# iter 5500 || Loss: 1.6038 ||Saving state, iter: 5500
# timer: 0.1871 sec.
# iter 5510 || Loss: 1.2178 ||timer: 0.1869 sec.
# iter 5520 || Loss: 1.6931 ||timer: 0.1872 sec.
# iter 5530 || Loss: 2.7043 ||timer: 0.1872 sec.
# iter 5540 || Loss: 2.6012 ||timer: 0.1873 sec.
# iter 5550 || Loss: 1.3695 ||timer: 0.1873 sec.
# iter 5560 || Loss: 0.9946 ||timer: 0.1875 sec.
# iter 5570 || Loss: 1.0229 ||timer: 0.1871 sec.
# iter 5580 || Loss: 1.3730 ||timer: 0.1875 sec.
# iter 5590 || Loss: 2.8049 ||timer: 0.2128 sec.
# iter 5600 || Loss: 1.3973 ||timer: 0.1885 sec.
# iter 5610 || Loss: 4.9762 ||timer: 0.1871 sec.
# iter 5620 || Loss: 0.5071 ||timer: 0.1879 sec.
# iter 5630 || Loss: 0.7050 ||timer: 0.1874 sec.
# iter 5640 || Loss: 1.7967 ||timer: 0.1873 sec.
# iter 5650 || Loss: 1.2555 ||timer: 0.1873 sec.
# iter 5660 || Loss: 1.6685 ||timer: 0.1872 sec.
# iter 5670 || Loss: 0.7953 ||timer: 0.1869 sec.
# iter 5680 || Loss: 0.9152 ||timer: 0.1872 sec.
# iter 5690 || Loss: 1.1903 ||timer: 0.1869 sec.
# iter 5700 || Loss: 0.5182 ||timer: 0.1874 sec.
# iter 5710 || Loss: 1.4325 ||timer: 0.1870 sec.
# iter 5720 || Loss: 1.0797 ||timer: 0.1871 sec.
# iter 5730 || Loss: 1.2888 ||timer: 0.1876 sec.
# iter 5740 || Loss: 1.4302 ||timer: 0.1874 sec.
# iter 5750 || Loss: 5.6352 ||timer: 0.1875 sec.
# iter 5760 || Loss: 1.3509 ||timer: 0.1871 sec.
# iter 5770 || Loss: 0.9600 ||timer: 0.1871 sec.
# iter 5780 || Loss: 1.1627 ||timer: 0.1873 sec.
# iter 5790 || Loss: 1.5663 ||timer: 0.1874 sec.
# iter 5800 || Loss: 4.1168 ||timer: 0.1872 sec.
# iter 5810 || Loss: 1.1890 ||timer: 0.1874 sec.
# iter 5820 || Loss: 1.5890 ||timer: 0.1872 sec.
# iter 5830 || Loss: 1.6614 ||timer: 0.1878 sec.
# iter 5840 || Loss: 1.5546 ||timer: 0.1871 sec.
# iter 5850 || Loss: 0.7665 ||timer: 0.1875 sec.
# iter 5860 || Loss: 1.1339 ||timer: 0.1871 sec.
# iter 5870 || Loss: 1.1121 ||timer: 0.1879 sec.
# iter 5880 || Loss: 5.8539 ||timer: 0.1874 sec.
# iter 5890 || Loss: 1.3059 ||timer: 0.1873 sec.
# iter 5900 || Loss: 2.1058 ||timer: 0.1895 sec.
# iter 5910 || Loss: 1.1488 ||timer: 0.1873 sec.
# iter 5920 || Loss: 0.7592 ||timer: 0.1890 sec.
# iter 5930 || Loss: 2.4230 ||timer: 0.1870 sec.
# iter 5940 || Loss: 1.5224 ||timer: 0.1869 sec.
# iter 5950 || Loss: 1.4000 ||timer: 0.1872 sec.
# iter 5960 || Loss: 3.5687 ||timer: 0.1877 sec.
# iter 5970 || Loss: 1.0826 ||timer: 0.1869 sec.
# iter 5980 || Loss: 0.6756 ||timer: 0.1871 sec.
# iter 5990 || Loss: 1.2041 ||timer: 0.1874 sec.
# iter 6000 || Loss: 1.6421 ||Saving state, iter: 6000
# timer: 0.1877 sec.
# iter 6010 || Loss: 2.0969 ||timer: 0.1869 sec.
# iter 6020 || Loss: 1.3049 ||timer: 0.1874 sec.
# iter 6030 || Loss: 1.1470 ||timer: 0.1871 sec.
# iter 6040 || Loss: 1.8271 ||timer: 0.1876 sec.
# iter 6050 || Loss: 1.2339 ||timer: 0.1873 sec.
# iter 6060 || Loss: 2.8664 ||timer: 0.1871 sec.
# iter 6070 || Loss: 1.7409 ||timer: 0.1872 sec.
# iter 6080 || Loss: 1.5198 ||timer: 0.1874 sec.
# iter 6090 || Loss: 0.9463 ||timer: 0.1878 sec.
# iter 6100 || Loss: 1.2757 ||timer: 0.1868 sec.
# iter 6110 || Loss: 2.6296 ||timer: 0.1871 sec.
# iter 6120 || Loss: 1.1551 ||timer: 0.1877 sec.
# iter 6130 || Loss: 2.6868 ||timer: 0.1868 sec.
# iter 6140 || Loss: 1.6825 ||timer: 0.1872 sec.
# iter 6150 || Loss: 0.8818 ||timer: 0.1870 sec.
# iter 6160 || Loss: 1.8193 ||timer: 0.1874 sec.
# iter 6170 || Loss: 1.1943 ||timer: 0.1878 sec.
# iter 6180 || Loss: 1.5940 ||timer: 0.1871 sec.
# iter 6190 || Loss: 1.2496 ||timer: 0.1087 sec.
# iter 6200 || Loss: 0.3807 ||timer: 0.1876 sec.
# iter 6210 || Loss: 1.9117 ||timer: 0.1869 sec.
# iter 6220 || Loss: 0.4906 ||timer: 0.1873 sec.
# iter 6230 || Loss: 1.4766 ||timer: 0.1869 sec.
# iter 6240 || Loss: 1.0052 ||timer: 0.1870 sec.
# iter 6250 || Loss: 3.6662 ||timer: 0.1874 sec.
# iter 6260 || Loss: 0.5883 ||timer: 0.1873 sec.
# iter 6270 || Loss: 1.8503 ||timer: 0.1876 sec.
# iter 6280 || Loss: 1.4150 ||timer: 0.1872 sec.
# iter 6290 || Loss: 12.1259 ||timer: 0.1874 sec.
# iter 6300 || Loss: 1.5861 ||timer: 0.1897 sec.
# iter 6310 || Loss: 1.5198 ||timer: 0.1874 sec.
# iter 6320 || Loss: 1.8591 ||timer: 0.1875 sec.
# iter 6330 || Loss: 1.5003 ||timer: 0.1870 sec.
# iter 6340 || Loss: 4.1557 ||timer: 0.1871 sec.
# iter 6350 || Loss: 1.2476 ||timer: 0.1877 sec.
# iter 6360 || Loss: 0.8909 ||timer: 0.1910 sec.
# iter 6370 || Loss: 1.4066 ||timer: 0.1873 sec.
# iter 6380 || Loss: 0.4643 ||timer: 0.1875 sec.
# iter 6390 || Loss: 1.2890 ||timer: 0.1870 sec.
# iter 6400 || Loss: 1.9554 ||timer: 0.1879 sec.
# iter 6410 || Loss: 1.7160 ||timer: 0.1871 sec.
# iter 6420 || Loss: 1.4440 ||timer: 0.1870 sec.
# iter 6430 || Loss: 1.6224 ||timer: 0.1869 sec.
# iter 6440 || Loss: 1.7473 ||timer: 0.1872 sec.
# iter 6450 || Loss: 1.1908 ||timer: 0.1869 sec.
# iter 6460 || Loss: 0.9596 ||timer: 0.1870 sec.
# iter 6470 || Loss: 2.6677 ||timer: 0.1874 sec.
# iter 6480 || Loss: 1.4787 ||timer: 0.1872 sec.
# iter 6490 || Loss: 2.9229 ||timer: 0.1878 sec.
# iter 6500 || Loss: 0.4875 ||Saving state, iter: 6500
# timer: 0.1876 sec.
# iter 6510 || Loss: 3.9048 ||timer: 0.1913 sec.
# iter 6520 || Loss: 6.3090 ||timer: 0.1904 sec.
# iter 6530 || Loss: 1.6815 ||timer: 0.1873 sec.
# iter 6540 || Loss: 3.7024 ||timer: 0.1873 sec.
# iter 6550 || Loss: 1.8726 ||timer: 0.1874 sec.
# iter 6560 || Loss: 0.8535 ||timer: 0.1870 sec.
# iter 6570 || Loss: 0.9704 ||timer: 0.1873 sec.
# iter 6580 || Loss: 0.9988 ||timer: 0.1876 sec.
# iter 6590 || Loss: 0.9882 ||timer: 0.1871 sec.
# iter 6600 || Loss: 1.9789 ||timer: 0.1870 sec.
# iter 6610 || Loss: 1.4353 ||timer: 0.1875 sec.
# iter 6620 || Loss: 2.5385 ||timer: 0.1872 sec.
# iter 6630 || Loss: 1.9820 ||timer: 0.1874 sec.
# iter 6640 || Loss: 1.5116 ||timer: 0.1869 sec.
# iter 6650 || Loss: 1.9197 ||timer: 0.1874 sec.
# iter 6660 || Loss: 1.0066 ||timer: 0.1867 sec.
# iter 6670 || Loss: 1.4872 ||timer: 0.1881 sec.
# iter 6680 || Loss: 1.0647 ||timer: 0.1884 sec.
# iter 6690 || Loss: 1.6581 ||timer: 0.1871 sec.
# iter 6700 || Loss: 2.9858 ||timer: 0.1915 sec.
# iter 6710 || Loss: 1.3825 ||timer: 0.1878 sec.
# iter 6720 || Loss: 0.7474 ||timer: 0.1869 sec.
# iter 6730 || Loss: 0.4967 ||timer: 0.1873 sec.
# iter 6740 || Loss: 1.7997 ||timer: 0.1909 sec.
# iter 6750 || Loss: 0.9332 ||timer: 0.1871 sec.
# iter 6760 || Loss: 3.3634 ||timer: 0.1871 sec.
# iter 6770 || Loss: 2.3497 ||timer: 0.1870 sec.
# iter 6780 || Loss: 1.5722 ||timer: 0.1877 sec.
# iter 6790 || Loss: 2.8803 ||timer: 0.1873 sec.
# iter 6800 || Loss: 1.5107 ||timer: 0.1869 sec.
# iter 6810 || Loss: 2.2752 ||timer: 0.1876 sec.
# iter 6820 || Loss: 1.6440 ||timer: 0.1878 sec.
# iter 6830 || Loss: 1.6976 ||timer: 0.1868 sec.
# iter 6840 || Loss: 1.2650 ||timer: 0.1871 sec.
# iter 6850 || Loss: 1.4842 ||timer: 0.1870 sec.
# iter 6860 || Loss: 2.4282 ||timer: 0.1873 sec.
# iter 6870 || Loss: 0.6530 ||timer: 0.1872 sec.
# iter 6880 || Loss: 1.9432 ||timer: 0.1871 sec.
# iter 6890 || Loss: 0.5237 ||timer: 0.1872 sec.
# iter 6900 || Loss: 2.7967 ||timer: 0.1876 sec.
# iter 6910 || Loss: 1.8356 ||timer: 0.1873 sec.
# iter 6920 || Loss: 1.2633 ||timer: 0.1869 sec.
# iter 6930 || Loss: 1.0502 ||timer: 0.1868 sec.
# iter 6940 || Loss: 0.9831 ||timer: 0.1871 sec.
# iter 6950 || Loss: 1.9249 ||timer: 0.1868 sec.
# iter 6960 || Loss: 1.6526 ||timer: 0.1877 sec.
# iter 6970 || Loss: 1.6370 ||timer: 0.1866 sec.
# iter 6980 || Loss: 2.4310 ||timer: 0.1943 sec.
# iter 6990 || Loss: 0.9448 ||timer: 0.1887 sec.
# iter 7000 || Loss: 4.3764 ||Saving state, iter: 7000
# timer: 0.1881 sec.
# iter 7010 || Loss: 2.4588 ||timer: 0.1871 sec.
# iter 7020 || Loss: 1.9488 ||timer: 0.1870 sec.
# iter 7030 || Loss: 2.0780 ||timer: 0.1880 sec.
# iter 7040 || Loss: 1.3431 ||timer: 0.1873 sec.
# iter 7050 || Loss: 1.1761 ||timer: 0.1873 sec.
# iter 7060 || Loss: 1.4263 ||timer: 0.1870 sec.
# iter 7070 || Loss: 0.9773 ||timer: 0.1878 sec.
# iter 7080 || Loss: 1.7968 ||timer: 0.1898 sec.
# iter 7090 || Loss: 2.6382 ||timer: 0.1871 sec.
# iter 7100 || Loss: 1.3854 ||timer: 0.1876 sec.
# iter 7110 || Loss: 0.9090 ||timer: 0.1876 sec.
# iter 7120 || Loss: 1.7549 ||timer: 0.1873 sec.
# iter 7130 || Loss: 1.2984 ||timer: 0.1875 sec.
# iter 7140 || Loss: 1.5692 ||timer: 0.1869 sec.
# iter 7150 || Loss: 0.9291 ||timer: 0.1878 sec.
# iter 7160 || Loss: 1.0295 ||timer: 0.1870 sec.
# iter 7170 || Loss: 2.1291 ||timer: 0.1870 sec.
# iter 7180 || Loss: 3.2239 ||timer: 0.1869 sec.
# iter 7190 || Loss: 0.7602 ||timer: 0.1900 sec.
# iter 7200 || Loss: 1.8052 ||timer: 0.1870 sec.
# iter 7210 || Loss: 1.2578 ||timer: 0.1869 sec.
# iter 7220 || Loss: 0.9292 ||timer: 0.1883 sec.
# iter 7230 || Loss: 1.0625 ||timer: 0.1869 sec.
# iter 7240 || Loss: 1.4172 ||timer: 0.1870 sec.
# iter 7250 || Loss: 1.7436 ||timer: 0.1873 sec.
# iter 7260 || Loss: 1.5478 ||timer: 0.1875 sec.
# iter 7270 || Loss: 3.7753 ||timer: 0.1870 sec.
# iter 7280 || Loss: 0.6274 ||timer: 0.1870 sec.
# iter 7290 || Loss: 1.5439 ||timer: 0.1873 sec.
# iter 7300 || Loss: 1.0051 ||timer: 0.1873 sec.
# iter 7310 || Loss: 0.8265 ||timer: 0.1870 sec.
# iter 7320 || Loss: 1.1681 ||timer: 0.1876 sec.
# iter 7330 || Loss: 1.1414 ||timer: 0.1874 sec.
# iter 7340 || Loss: 1.9860 ||timer: 0.1869 sec.
# iter 7350 || Loss: 0.7004 ||timer: 0.1880 sec.
# iter 7360 || Loss: 1.2749 ||timer: 0.1869 sec.
# iter 7370 || Loss: 0.9888 ||timer: 0.1874 sec.
# iter 7380 || Loss: 2.3631 ||timer: 0.1874 sec.
# iter 7390 || Loss: 0.7594 ||timer: 0.1873 sec.
# iter 7400 || Loss: 2.8470 ||timer: 0.1869 sec.
# iter 7410 || Loss: 1.9183 ||timer: 0.1881 sec.
# iter 7420 || Loss: 2.3446 ||timer: 0.1871 sec.
# iter 7430 || Loss: 2.2427 ||timer: 0.1873 sec.
# iter 7440 || Loss: 2.2229 ||timer: 0.1878 sec.
# iter 7450 || Loss: 1.6483 ||timer: 0.1869 sec.
# iter 7460 || Loss: 1.7803 ||timer: 0.1873 sec.
# iter 7470 || Loss: 1.0421 ||timer: 0.1870 sec.
# iter 7480 || Loss: 0.7260 ||timer: 0.1873 sec.
# iter 7490 || Loss: 1.3178 ||timer: 0.1873 sec.
# iter 7500 || Loss: 1.3325 ||Saving state, iter: 7500
# timer: 0.1870 sec.
# iter 7510 || Loss: 0.9973 ||timer: 0.1870 sec.
# iter 7520 || Loss: 2.2870 ||timer: 0.1870 sec.
# iter 7530 || Loss: 0.7193 ||timer: 0.1873 sec.
# iter 7540 || Loss: 2.6596 ||timer: 0.1874 sec.
# iter 7550 || Loss: 1.4427 ||timer: 0.1919 sec.
# iter 7560 || Loss: 1.7298 ||timer: 0.1874 sec.
# iter 7570 || Loss: 0.9528 ||timer: 0.1874 sec.
# iter 7580 || Loss: 1.1111 ||timer: 0.1874 sec.
# iter 7590 || Loss: 1.2418 ||timer: 0.1873 sec.
# iter 7600 || Loss: 1.9164 ||timer: 0.1873 sec.
# iter 7610 || Loss: 2.0206 ||timer: 0.1876 sec.
# iter 7620 || Loss: 2.3737 ||timer: 0.1874 sec.
# iter 7630 || Loss: 2.1433 ||timer: 0.1873 sec.
# iter 7640 || Loss: 2.5633 ||timer: 0.1873 sec.
# iter 7650 || Loss: 1.0986 ||timer: 0.1873 sec.
# iter 7660 || Loss: 1.5815 ||timer: 0.1917 sec.
# iter 7670 || Loss: 2.1461 ||timer: 0.1878 sec.
# iter 7680 || Loss: 7.1994 ||timer: 0.1871 sec.
# iter 7690 || Loss: 1.9245 ||timer: 0.1872 sec.
# iter 7700 || Loss: 1.8481 ||timer: 0.1871 sec.
# iter 7710 || Loss: 1.1326 ||timer: 0.1873 sec.
# iter 7720 || Loss: 1.9168 ||timer: 0.1871 sec.
# iter 7730 || Loss: 0.7274 ||timer: 0.1902 sec.
# iter 7740 || Loss: 0.5587 ||timer: 0.1871 sec.
# iter 7750 || Loss: 0.9274 ||timer: 0.1886 sec.
# iter 7760 || Loss: 1.1897 ||timer: 0.1906 sec.
# iter 7770 || Loss: 1.4063 ||timer: 0.1878 sec.
# iter 7780 || Loss: 1.5638 ||timer: 0.1869 sec.
# iter 7790 || Loss: 1.3809 ||timer: 0.1873 sec.
# iter 7800 || Loss: 1.0648 ||timer: 0.1877 sec.
# iter 7810 || Loss: 1.4128 ||timer: 0.1870 sec.
# iter 7820 || Loss: 0.9827 ||timer: 0.1872 sec.
# iter 7830 || Loss: 1.2881 ||timer: 0.1900 sec.
# iter 7840 || Loss: 0.5756 ||timer: 0.1876 sec.
# iter 7850 || Loss: 1.9847 ||timer: 0.1876 sec.
# iter 7860 || Loss: 0.7229 ||timer: 0.1873 sec.
# iter 7870 || Loss: 1.1820 ||timer: 0.1875 sec.
# iter 7880 || Loss: 2.2363 ||timer: 0.1871 sec.
# iter 7890 || Loss: 4.8648 ||timer: 0.1879 sec.
# iter 7900 || Loss: 0.8393 ||timer: 0.1870 sec.
# iter 7910 || Loss: 1.7985 ||timer: 0.1875 sec.
# iter 7920 || Loss: 1.3072 ||timer: 0.2233 sec.
# iter 7930 || Loss: 2.0529 ||timer: 0.1881 sec.
# iter 7940 || Loss: 0.6976 ||timer: 0.1901 sec.
# iter 7950 || Loss: 1.3770 ||timer: 0.1878 sec.
# iter 7960 || Loss: 0.9696 ||timer: 0.1876 sec.
# iter 7970 || Loss: 1.4274 ||timer: 0.1870 sec.
# iter 7980 || Loss: 2.9632 ||timer: 0.1869 sec.
# iter 7990 || Loss: 1.3822 ||Change learning rate to:  1.0000000000000003e-05
# timer: 0.1900 sec.
# iter 8000 || Loss: 0.8506 ||Saving state, iter: 8000
# timer: 0.1870 sec.
# iter 8010 || Loss: 1.1560 ||timer: 0.1946 sec.
# iter 8020 || Loss: 0.8143 ||timer: 0.1917 sec.
# iter 8030 || Loss: 2.3434 ||timer: 0.1870 sec.
# iter 8040 || Loss: 0.9126 ||timer: 0.1874 sec.
# iter 8050 || Loss: 0.4778 ||timer: 0.1876 sec.
# iter 8060 || Loss: 1.4947 ||timer: 0.1869 sec.
# iter 8070 || Loss: 1.6692 ||timer: 0.1869 sec.
# iter 8080 || Loss: 0.7972 ||timer: 0.1875 sec.
# iter 8090 || Loss: 2.0069 ||timer: 0.1874 sec.
# iter 8100 || Loss: 2.4001 ||timer: 0.1877 sec.
# iter 8110 || Loss: 0.9577 ||timer: 0.1870 sec.
# iter 8120 || Loss: 2.0566 ||timer: 0.1872 sec.
# iter 8130 || Loss: 2.9853 ||timer: 0.1867 sec.
# iter 8140 || Loss: 2.2135 ||timer: 0.1870 sec.
# iter 8150 || Loss: 2.1602 ||timer: 0.2166 sec.
# iter 8160 || Loss: 1.5498 ||timer: 0.1871 sec.
# iter 8170 || Loss: 1.1151 ||timer: 0.1877 sec.
# iter 8180 || Loss: 0.7678 ||timer: 0.1872 sec.
# iter 8190 || Loss: 0.8898 ||timer: 0.1869 sec.
# iter 8200 || Loss: 1.6517 ||timer: 0.1873 sec.
# iter 8210 || Loss: 2.0785 ||timer: 0.1875 sec.
# iter 8220 || Loss: 0.7472 ||timer: 0.1870 sec.
# iter 8230 || Loss: 0.9175 ||timer: 0.1874 sec.
# iter 8240 || Loss: 2.3437 ||timer: 0.1869 sec.
# iter 8250 || Loss: 3.6155 ||timer: 0.1873 sec.
# iter 8260 || Loss: 2.1512 ||timer: 0.1871 sec.
# iter 8270 || Loss: 1.9410 ||timer: 0.1872 sec.
# iter 8280 || Loss: 1.2956 ||timer: 0.1872 sec.
# iter 8290 || Loss: 0.8582 ||timer: 0.1875 sec.
# iter 8300 || Loss: 1.1237 ||timer: 0.1876 sec.
# iter 8310 || Loss: 2.2311 ||timer: 0.1871 sec.
# iter 8320 || Loss: 1.6082 ||timer: 0.1870 sec.
# iter 8330 || Loss: 2.1394 ||timer: 0.1871 sec.
# iter 8340 || Loss: 0.6057 ||timer: 0.1908 sec.
# iter 8350 || Loss: 2.3678 ||timer: 0.1872 sec.
# iter 8360 || Loss: 0.7807 ||timer: 0.1870 sec.
# iter 8370 || Loss: 2.8417 ||timer: 0.1872 sec.
# iter 8380 || Loss: 0.6439 ||timer: 0.1875 sec.
# iter 8390 || Loss: 1.5687 ||timer: 0.1877 sec.
# iter 8400 || Loss: 1.4950 ||timer: 0.1876 sec.
# iter 8410 || Loss: 1.9346 ||timer: 0.1870 sec.
# iter 8420 || Loss: 1.4193 ||timer: 0.1870 sec.
# iter 8430 || Loss: 0.6710 ||timer: 0.1874 sec.
# iter 8440 || Loss: 1.9615 ||timer: 0.1874 sec.
# iter 8450 || Loss: 1.0532 ||timer: 0.1873 sec.
# iter 8460 || Loss: 2.3730 ||timer: 0.1916 sec.
# iter 8470 || Loss: 1.7718 ||timer: 0.1871 sec.
# iter 8480 || Loss: 2.2171 ||timer: 0.1879 sec.
# iter 8490 || Loss: 0.7088 ||timer: 0.1868 sec.
# iter 8500 || Loss: 2.1544 ||Saving state, iter: 8500
# timer: 0.1873 sec.
# iter 8510 || Loss: 1.2580 ||timer: 0.1992 sec.
# iter 8520 || Loss: 7.7816 ||timer: 0.1872 sec.
# iter 8530 || Loss: 1.4428 ||timer: 0.1868 sec.
# iter 8540 || Loss: 1.1056 ||timer: 0.1870 sec.
# iter 8550 || Loss: 5.4609 ||timer: 0.1873 sec.
# iter 8560 || Loss: 1.5752 ||timer: 0.1872 sec.
# iter 8570 || Loss: 0.9317 ||timer: 0.1873 sec.
# iter 8580 || Loss: 1.3109 ||timer: 0.1871 sec.
# iter 8590 || Loss: 1.3782 ||timer: 0.1876 sec.
# iter 8600 || Loss: 1.0915 ||timer: 0.1871 sec.
# iter 8610 || Loss: 1.3700 ||timer: 0.1872 sec.
# iter 8620 || Loss: 1.8277 ||timer: 0.1872 sec.
# iter 8630 || Loss: 1.0233 ||timer: 0.1904 sec.
# iter 8640 || Loss: 1.4413 ||timer: 0.1878 sec.
# iter 8650 || Loss: 1.2127 ||timer: 0.1877 sec.
# iter 8660 || Loss: 2.7773 ||timer: 0.1869 sec.
# iter 8670 || Loss: 0.7919 ||timer: 0.1869 sec.
# iter 8680 || Loss: 2.9183 ||timer: 0.1877 sec.
# iter 8690 || Loss: 1.0660 ||timer: 0.1870 sec.
# iter 8700 || Loss: 1.0209 ||timer: 0.1873 sec.
# iter 8710 || Loss: 1.2826 ||timer: 0.1880 sec.
# iter 8720 || Loss: 1.1693 ||timer: 0.1919 sec.
# iter 8730 || Loss: 0.6093 ||timer: 0.1875 sec.
# iter 8740 || Loss: 2.9855 ||timer: 0.1873 sec.
# iter 8750 || Loss: 1.1799 ||timer: 0.1875 sec.
# iter 8760 || Loss: 1.4616 ||timer: 0.1869 sec.
# iter 8770 || Loss: 1.2364 ||timer: 0.1881 sec.
# iter 8780 || Loss: 1.7398 ||timer: 0.1871 sec.
# iter 8790 || Loss: 0.7157 ||timer: 0.1875 sec.
# iter 8800 || Loss: 1.3291 ||timer: 0.1871 sec.
# iter 8810 || Loss: 1.7857 ||timer: 0.1873 sec.
# iter 8820 || Loss: 2.8109 ||timer: 0.1868 sec.
# iter 8830 || Loss: 2.1725 ||timer: 0.1869 sec.
# iter 8840 || Loss: 1.3550 ||timer: 0.1871 sec.
# iter 8850 || Loss: 1.4084 ||timer: 0.1872 sec.
# iter 8860 || Loss: 2.4037 ||timer: 0.1873 sec.
# iter 8870 || Loss: 1.0278 ||timer: 0.1874 sec.
# iter 8880 || Loss: 0.9323 ||timer: 0.1873 sec.
# iter 8890 || Loss: 1.0026 ||timer: 0.1873 sec.
# iter 8900 || Loss: 1.1872 ||timer: 0.1881 sec.
# iter 8910 || Loss: 1.7634 ||timer: 0.1874 sec.
# iter 8920 || Loss: 0.5921 ||timer: 0.1877 sec.
# iter 8930 || Loss: 1.0755 ||timer: 0.1873 sec.
# iter 8940 || Loss: 1.0824 ||timer: 0.1875 sec.
# iter 8950 || Loss: 1.1220 ||timer: 0.1874 sec.
# iter 8960 || Loss: 1.9983 ||timer: 0.1875 sec.
# iter 8970 || Loss: 2.3123 ||timer: 0.1877 sec.
# iter 8980 || Loss: 1.4935 ||timer: 0.1868 sec.
# iter 8990 || Loss: 1.3434 ||timer: 0.1876 sec.
# iter 9000 || Loss: 1.6752 ||Saving state, iter: 9000
# timer: 0.1876 sec.
# iter 9010 || Loss: 2.1789 ||timer: 0.1907 sec.
# iter 9020 || Loss: 1.0178 ||timer: 0.1874 sec.
# iter 9030 || Loss: 1.5531 ||timer: 0.1874 sec.
# iter 9040 || Loss: 1.9203 ||timer: 0.1872 sec.
# iter 9050 || Loss: 1.8184 ||timer: 0.1869 sec.
# iter 9060 || Loss: 4.4188 ||timer: 0.1872 sec.
# iter 9070 || Loss: 2.6931 ||timer: 0.1871 sec.
# iter 9080 || Loss: 2.9093 ||timer: 0.2156 sec.
# iter 9090 || Loss: 0.8974 ||timer: 0.1872 sec.
# iter 9100 || Loss: 0.9447 ||timer: 0.1869 sec.
# iter 9110 || Loss: 1.2261 ||timer: 0.1876 sec.
# iter 9120 || Loss: 1.9760 ||timer: 0.1876 sec.
# iter 9130 || Loss: 0.9311 ||timer: 0.1888 sec.
# iter 9140 || Loss: 0.7516 ||timer: 0.1920 sec.
# iter 9150 || Loss: 1.2320 ||timer: 0.1875 sec.
# iter 9160 || Loss: 1.3684 ||timer: 0.1875 sec.
# iter 9170 || Loss: 1.5500 ||timer: 0.1878 sec.
# iter 9180 || Loss: 0.6953 ||timer: 0.1904 sec.
# iter 9190 || Loss: 1.9872 ||timer: 0.1878 sec.
# iter 9200 || Loss: 1.5660 ||timer: 0.1872 sec.
# iter 9210 || Loss: 3.1092 ||timer: 0.1876 sec.
# iter 9220 || Loss: 1.4054 ||timer: 0.1873 sec.
# iter 9230 || Loss: 0.4003 ||timer: 0.1869 sec.
# iter 9240 || Loss: 1.3558 ||timer: 0.1870 sec.
# iter 9250 || Loss: 1.7194 ||timer: 0.1937 sec.
# iter 9260 || Loss: 0.8379 ||timer: 0.1873 sec.
# iter 9270 || Loss: 0.8039 ||timer: 0.1873 sec.
# iter 9280 || Loss: 2.0270 ||timer: 0.1874 sec.
# iter 9290 || Loss: 2.5355 ||timer: 0.1869 sec.
# iter 9300 || Loss: 1.0821 ||timer: 0.1870 sec.
# iter 9310 || Loss: 1.3153 ||timer: 0.1877 sec.
# iter 9320 || Loss: 2.1807 ||timer: 0.1874 sec.
# iter 9330 || Loss: 1.2867 ||timer: 0.1874 sec.
# iter 9340 || Loss: 1.5693 ||timer: 0.1875 sec.
# iter 9350 || Loss: 0.7961 ||timer: 0.1873 sec.
# iter 9360 || Loss: 3.0555 ||timer: 0.1875 sec.
# iter 9370 || Loss: 0.9706 ||timer: 0.1871 sec.
# iter 9380 || Loss: 1.4421 ||timer: 0.1872 sec.
# iter 9390 || Loss: 2.2220 ||timer: 0.1971 sec.
# iter 9400 || Loss: 3.1724 ||timer: 0.1870 sec.
# iter 9410 || Loss: 2.1249 ||timer: 0.1870 sec.
# iter 9420 || Loss: 1.8874 ||timer: 0.1874 sec.
# iter 9430 || Loss: 0.5321 ||timer: 0.1873 sec.
# iter 9440 || Loss: 1.1209 ||timer: 0.1873 sec.
# iter 9450 || Loss: 1.9156 ||timer: 0.1872 sec.
# iter 9460 || Loss: 1.1227 ||timer: 0.1876 sec.
# iter 9470 || Loss: 1.6266 ||timer: 0.1871 sec.
# iter 9480 || Loss: 2.2726 ||timer: 0.1872 sec.
# iter 9490 || Loss: 2.0040 ||timer: 0.1872 sec.
# iter 9500 || Loss: 1.0627 ||Saving state, iter: 9500
# timer: 0.1870 sec.
# iter 9510 || Loss: 1.1334 ||timer: 0.1878 sec.
# iter 9520 || Loss: 2.6876 ||timer: 0.1880 sec.
# iter 9530 || Loss: 2.0878 ||timer: 0.1933 sec.
# iter 9540 || Loss: 2.1462 ||timer: 0.1883 sec.
# iter 9550 || Loss: 0.8696 ||timer: 0.1873 sec.
# iter 9560 || Loss: 1.7710 ||timer: 0.1871 sec.
# iter 9570 || Loss: 1.2946 ||timer: 0.1903 sec.
# iter 9580 || Loss: 1.4571 ||timer: 0.1872 sec.
# iter 9590 || Loss: 3.4115 ||timer: 0.1873 sec.
# iter 9600 || Loss: 0.6483 ||timer: 0.1870 sec.
# iter 9610 || Loss: 1.4348 ||timer: 0.1905 sec.
# iter 9620 || Loss: 1.6015 ||timer: 0.1918 sec.
# iter 9630 || Loss: 1.4760 ||timer: 0.1871 sec.
# iter 9640 || Loss: 0.8557 ||timer: 0.1874 sec.
# iter 9650 || Loss: 0.7848 ||timer: 0.1873 sec.
# iter 9660 || Loss: 2.7845 ||timer: 0.1955 sec.
# iter 9670 || Loss: 1.2679 ||timer: 0.1877 sec.
# iter 9680 || Loss: 0.8688 ||timer: 0.1874 sec.
# iter 9690 || Loss: 4.5464 ||timer: 0.1871 sec.
# iter 9700 || Loss: 1.8178 ||timer: 0.1876 sec.
# iter 9710 || Loss: 2.7292 ||timer: 0.1876 sec.
# iter 9720 || Loss: 1.1373 ||timer: 0.1874 sec.
# iter 9730 || Loss: 3.3130 ||timer: 0.1871 sec.
# iter 9740 || Loss: 1.6559 ||timer: 0.1870 sec.
# iter 9750 || Loss: 0.7255 ||timer: 0.1869 sec.
# iter 9760 || Loss: 2.0627 ||timer: 0.1874 sec.
# iter 9770 || Loss: 1.5559 ||timer: 0.1870 sec.
# iter 9780 || Loss: 1.5587 ||timer: 0.1872 sec.
# iter 9790 || Loss: 1.7390 ||timer: 0.1874 sec.
# iter 9800 || Loss: 0.8332 ||timer: 0.1873 sec.
# iter 9810 || Loss: 1.9644 ||timer: 0.1880 sec.
# iter 9820 || Loss: 1.6376 ||timer: 0.1871 sec.
# iter 9830 || Loss: 0.9324 ||timer: 0.1871 sec.
# iter 9840 || Loss: 1.1745 ||timer: 0.1871 sec.
# iter 9850 || Loss: 3.1947 ||timer: 0.1877 sec.
# iter 9860 || Loss: 0.8319 ||timer: 0.1871 sec.
# iter 9870 || Loss: 0.8574 ||timer: 0.1870 sec.
# iter 9880 || Loss: 0.8155 ||timer: 0.1873 sec.
# iter 9890 || Loss: 2.2734 ||timer: 0.1870 sec.
# iter 9900 || Loss: 0.4611 ||timer: 0.1893 sec.
# iter 9910 || Loss: 2.1531 ||timer: 0.1876 sec.
# iter 9920 || Loss: 1.6725 ||timer: 0.1874 sec.
# iter 9930 || Loss: 1.8333 ||timer: 0.1868 sec.
# iter 9940 || Loss: 1.5942 ||timer: 0.1874 sec.
# iter 9950 || Loss: 1.4335 ||timer: 0.1870 sec.
# iter 9960 || Loss: 1.4275 ||timer: 0.1875 sec.
# iter 9970 || Loss: 1.4329 ||timer: 0.1872 sec.
# iter 9980 || Loss: 0.9988 ||timer: 0.1875 sec.
# iter 9990 || Loss: 1.3299 ||timer: 0.1876 sec.
# iter 10000 || Loss: 1.1848 ||Saving state, iter: 10000
# timer: 0.1871 sec.
# iter 10010 || Loss: 0.7219 ||timer: 0.1947 sec.
# iter 10020 || Loss: 1.3586 ||timer: 0.1871 sec.
# iter 10030 || Loss: 0.6849 ||timer: 0.1868 sec.
# iter 10040 || Loss: 1.1283 ||timer: 0.1873 sec.
# iter 10050 || Loss: 0.8153 ||timer: 0.1867 sec.
# iter 10060 || Loss: 1.3587 ||timer: 0.1876 sec.
# iter 10070 || Loss: 0.5346 ||timer: 0.1872 sec.
# iter 10080 || Loss: 0.6450 ||timer: 0.1875 sec.
# iter 10090 || Loss: 0.8910 ||timer: 0.1887 sec.
# iter 10100 || Loss: 0.9462 ||timer: 0.1878 sec.
# iter 10110 || Loss: 0.9161 ||timer: 0.1870 sec.
# iter 10120 || Loss: 5.8897 ||timer: 0.1872 sec.
# iter 10130 || Loss: 0.5184 ||timer: 0.1870 sec.
# iter 10140 || Loss: 1.2758 ||timer: 0.1878 sec.
# iter 10150 || Loss: 1.2952 ||timer: 0.1873 sec.
# iter 10160 || Loss: 1.5466 ||timer: 0.1872 sec.
# iter 10170 || Loss: 0.9493 ||timer: 0.1868 sec.
# iter 10180 || Loss: 1.5375 ||timer: 0.1872 sec.
# iter 10190 || Loss: 1.3373 ||timer: 0.1868 sec.
# iter 10200 || Loss: 1.1540 ||timer: 0.1877 sec.
# iter 10210 || Loss: 0.4661 ||timer: 0.1868 sec.
# iter 10220 || Loss: 1.3315 ||timer: 0.1872 sec.
# iter 10230 || Loss: 5.4550 ||timer: 0.1874 sec.
# iter 10240 || Loss: 0.9632 ||timer: 0.1871 sec.
# iter 10250 || Loss: 1.7879 ||timer: 0.1875 sec.
# iter 10260 || Loss: 1.7281 ||timer: 0.1871 sec.
# iter 10270 || Loss: 0.6732 ||timer: 0.1870 sec.
# iter 10280 || Loss: 0.6863 ||timer: 0.1866 sec.
# iter 10290 || Loss: 1.0556 ||timer: 0.1880 sec.
# iter 10300 || Loss: 1.5211 ||timer: 0.1872 sec.
# iter 10310 || Loss: 1.2030 ||timer: 0.1871 sec.
# iter 10320 || Loss: 1.6777 ||timer: 0.1872 sec.
# iter 10330 || Loss: 1.1557 ||timer: 0.1874 sec.
# iter 10340 || Loss: 1.7515 ||timer: 0.1870 sec.
# iter 10350 || Loss: 0.5450 ||timer: 0.1872 sec.
# iter 10360 || Loss: 0.8801 ||timer: 0.1877 sec.
# iter 10370 || Loss: 2.8495 ||timer: 0.1876 sec.
# iter 10380 || Loss: 1.2419 ||timer: 0.1917 sec.
# iter 10390 || Loss: 1.2020 ||timer: 0.1893 sec.
# iter 10400 || Loss: 2.2134 ||timer: 0.1872 sec.
# iter 10410 || Loss: 1.4363 ||timer: 0.1875 sec.
# iter 10420 || Loss: 1.0858 ||timer: 0.1880 sec.
# iter 10430 || Loss: 2.9614 ||timer: 0.1869 sec.
# iter 10440 || Loss: 1.6431 ||timer: 0.1871 sec.
# iter 10450 || Loss: 1.0065 ||timer: 0.1872 sec.
# iter 10460 || Loss: 0.7799 ||timer: 0.1871 sec.
# iter 10470 || Loss: 1.4182 ||timer: 0.1876 sec.
# iter 10480 || Loss: 1.3763 ||timer: 0.1869 sec.
# iter 10490 || Loss: 1.0371 ||timer: 0.1876 sec.
# iter 10500 || Loss: 3.0394 ||Saving state, iter: 10500
# timer: 0.1872 sec.
# iter 10510 || Loss: 1.7076 ||timer: 0.1873 sec.
# iter 10520 || Loss: 0.8125 ||timer: 0.1877 sec.
# iter 10530 || Loss: 0.5166 ||timer: 0.1878 sec.
# iter 10540 || Loss: 2.6947 ||timer: 0.1873 sec.
# iter 10550 || Loss: 1.2531 ||timer: 0.1867 sec.
# iter 10560 || Loss: 0.8032 ||timer: 0.1871 sec.
# iter 10570 || Loss: 1.2666 ||timer: 0.1868 sec.
# iter 10580 || Loss: 4.1241 ||timer: 0.1870 sec.
# iter 10590 || Loss: 1.6930 ||timer: 0.1871 sec.
# iter 10600 || Loss: 0.5777 ||timer: 0.2141 sec.
# iter 10610 || Loss: 1.4181 ||timer: 0.2140 sec.
# iter 10620 || Loss: 2.6122 ||timer: 0.2185 sec.
# iter 10630 || Loss: 0.6711 ||timer: 0.2162 sec.
# iter 10640 || Loss: 1.8893 ||timer: 0.2113 sec.
# iter 10650 || Loss: 1.5309 ||timer: 0.3000 sec.
# iter 10660 || Loss: 0.8578 ||timer: 0.2745 sec.
# iter 10670 || Loss: 3.7989 ||timer: 0.1869 sec.
# iter 10680 || Loss: 1.5174 ||timer: 0.1872 sec.
# iter 10690 || Loss: 2.7685 ||timer: 0.1876 sec.
# iter 10700 || Loss: 1.4673 ||timer: 0.1874 sec.
# iter 10710 || Loss: 0.5619 ||timer: 0.1874 sec.
# iter 10720 || Loss: 0.7654 ||timer: 0.1873 sec.
# iter 10730 || Loss: 2.0520 ||timer: 0.1868 sec.
# iter 10740 || Loss: 0.7405 ||timer: 0.1881 sec.
# iter 10750 || Loss: 1.5890 ||timer: 0.1872 sec.
# iter 10760 || Loss: 1.5054 ||timer: 0.1873 sec.
# iter 10770 || Loss: 3.8343 ||timer: 0.1881 sec.
# iter 10780 || Loss: 1.0056 ||timer: 0.1873 sec.
# iter 10790 || Loss: 1.1317 ||timer: 0.1874 sec.
# iter 10800 || Loss: 0.8417 ||timer: 0.1877 sec.
# iter 10810 || Loss: 2.2710 ||timer: 0.1868 sec.
# iter 10820 || Loss: 1.2194 ||timer: 0.1872 sec.
# iter 10830 || Loss: 1.7962 ||timer: 0.1869 sec.
# iter 10840 || Loss: 4.5239 ||timer: 0.1875 sec.
# iter 10850 || Loss: 0.8901 ||timer: 0.1872 sec.
# iter 10860 || Loss: 1.2616 ||timer: 0.1870 sec.
# iter 10870 || Loss: 1.2582 ||timer: 0.1873 sec.
# iter 10880 || Loss: 0.8613 ||timer: 0.1869 sec.
# iter 10890 || Loss: 3.4103 ||timer: 0.1871 sec.
# iter 10900 || Loss: 2.5690 ||timer: 0.1876 sec.
# iter 10910 || Loss: 0.9835 ||timer: 0.1874 sec.
# iter 10920 || Loss: 1.3034 ||timer: 0.1872 sec.
# iter 10930 || Loss: 1.0623 ||timer: 0.1870 sec.
# iter 10940 || Loss: 1.0600 ||timer: 0.1870 sec.
# iter 10950 || Loss: 5.3083 ||timer: 0.1924 sec.
# iter 10960 || Loss: 2.6496 ||timer: 0.1094 sec.
# iter 10970 || Loss: 1.4845 ||timer: 0.1871 sec.
# iter 10980 || Loss: 1.3305 ||timer: 0.1880 sec.
# iter 10990 || Loss: 0.7237 ||timer: 0.1872 sec.
# iter 11000 || Loss: 1.1157 ||Saving state, iter: 11000
# timer: 0.1874 sec.
# iter 11010 || Loss: 1.6413 ||timer: 0.1874 sec.
# iter 11020 || Loss: 1.1188 ||timer: 0.1871 sec.
# iter 11030 || Loss: 3.2537 ||timer: 0.1876 sec.
# iter 11040 || Loss: 1.8092 ||timer: 0.1873 sec.
# iter 11050 || Loss: 2.2115 ||timer: 0.1876 sec.
# iter 11060 || Loss: 1.5927 ||timer: 0.1874 sec.
# iter 11070 || Loss: 1.3354 ||timer: 0.1873 sec.
# iter 11080 || Loss: 0.6418 ||timer: 0.1868 sec.
# iter 11090 || Loss: 2.7682 ||timer: 0.1874 sec.
# iter 11100 || Loss: 0.9380 ||timer: 0.1875 sec.
# iter 11110 || Loss: 1.5099 ||timer: 0.1869 sec.
# iter 11120 || Loss: 0.3343 ||timer: 0.1874 sec.
# iter 11130 || Loss: 1.0234 ||timer: 0.1870 sec.
# iter 11140 || Loss: 1.8390 ||timer: 0.1873 sec.
# iter 11150 || Loss: 2.4492 ||timer: 0.1876 sec.
# iter 11160 || Loss: 1.0530 ||timer: 0.1870 sec.
# iter 11170 || Loss: 1.0180 ||timer: 0.1872 sec.
# iter 11180 || Loss: 1.6779 ||timer: 0.1872 sec.
# iter 11190 || Loss: 1.7710 ||timer: 0.1870 sec.
# iter 11200 || Loss: 1.3473 ||timer: 0.1872 sec.
# iter 11210 || Loss: 1.0503 ||timer: 0.1870 sec.
# iter 11220 || Loss: 1.1746 ||timer: 0.1870 sec.
# iter 11230 || Loss: 0.7037 ||timer: 0.1869 sec.
# iter 11240 || Loss: 0.7339 ||timer: 0.1870 sec.
# iter 11250 || Loss: 0.8228 ||timer: 0.1872 sec.
# iter 11260 || Loss: 1.4092 ||timer: 0.1878 sec.
# iter 11270 || Loss: 3.7753 ||timer: 0.1871 sec.
# iter 11280 || Loss: 0.7126 ||timer: 0.1875 sec.
# iter 11290 || Loss: 1.7997 ||timer: 0.1879 sec.
# iter 11300 || Loss: 1.4702 ||timer: 0.1871 sec.
# iter 11310 || Loss: 0.8513 ||timer: 0.1870 sec.
# iter 11320 || Loss: 1.6329 ||timer: 0.1871 sec.
# iter 11330 || Loss: 1.9070 ||timer: 0.1877 sec.
# iter 11340 || Loss: 9.7921 ||timer: 0.1874 sec.
# iter 11350 || Loss: 0.8856 ||timer: 0.1868 sec.
# iter 11360 || Loss: 0.6130 ||timer: 0.1871 sec.
# iter 11370 || Loss: 2.6918 ||timer: 0.1869 sec.
# iter 11380 || Loss: 0.5373 ||timer: 0.1874 sec.
# iter 11390 || Loss: 3.5546 ||timer: 0.1876 sec.
# iter 11400 || Loss: 1.4162 ||timer: 0.1873 sec.
# iter 11410 || Loss: 1.1745 ||timer: 0.1870 sec.
# iter 11420 || Loss: 1.6796 ||timer: 0.1869 sec.
# iter 11430 || Loss: 2.5170 ||timer: 0.1870 sec.
# iter 11440 || Loss: 1.4934 ||timer: 0.1900 sec.
# iter 11450 || Loss: 1.4382 ||timer: 0.1873 sec.
# iter 11460 || Loss: 0.8778 ||timer: 0.1869 sec.
# iter 11470 || Loss: 0.8002 ||timer: 0.1870 sec.
# iter 11480 || Loss: 1.6967 ||timer: 0.1872 sec.
# iter 11490 || Loss: 1.2855 ||timer: 0.1870 sec.
# iter 11500 || Loss: 0.9286 ||Saving state, iter: 11500
# timer: 0.1868 sec.
# iter 11510 || Loss: 1.3797 ||timer: 0.1872 sec.
# iter 11520 || Loss: 3.4259 ||timer: 0.1870 sec.
# iter 11530 || Loss: 0.9857 ||timer: 0.1901 sec.
# iter 11540 || Loss: 1.3489 ||timer: 0.1880 sec.
# iter 11550 || Loss: 2.4380 ||timer: 0.1877 sec.
# iter 11560 || Loss: 0.6981 ||timer: 0.1890 sec.
# iter 11570 || Loss: 2.7899 ||timer: 0.1871 sec.
# iter 11580 || Loss: 1.1833 ||timer: 0.1874 sec.
# iter 11590 || Loss: 1.0806 ||timer: 0.1909 sec.
# iter 11600 || Loss: 0.9862 ||timer: 0.1870 sec.
# iter 11610 || Loss: 1.5638 ||timer: 0.1876 sec.
# iter 11620 || Loss: 1.7174 ||
